# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sanket Anand** <br>Data Scientist

# %% [markdown]
# *I am interested in data science because it is a fun activity for me which suits my style.*

# %% [markdown]
# ### The following code gives a sum of two integers

# %%
def sum(num1,num2):
    return num1+num2

# %% [markdown]
# ## My favourite foods <br>
# - Pizza
# - Dosa
# - Pie <br>
# ### Fav Sports
# 1. Cricket
# 2. Soccer
# 3. Pool <br>
# ### Making a table to show marksheets
# |Rohit|Rahul|Bunty|
# |---|---|---|
# |27|31|18|
